# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
import os
import seaborn as sns

# %%
pd.set_option('display.max_columns',300)

# %%
dados = []
for elem in os.listdir('json'):
    if 'json' in elem:
        dados.append(json.loads(open(os.path.join('json', elem),encoding='utf-8').read()) )

# %%
colunas_nivel = ['tempoParado',
    'tempoMovimentando',
    'tempoAtirando',
    'tempoRecarregando',
    'tempoSliding',
    'tempoDash',
    'tempoPulando',
    'tempoCaindo',
    'tempoAgachado',
    'quantidadeTiros',
    'quantidadeTirosAcertados',
    'quantidadeTirosAcertadosCausandoDano',
    'quantidadeTirosAcertadosSemCausarDano',
    'quantidadeTirosErrados',
    'quantidadeAgachado',
    'quantidadePulos',
    'quantidadeDash',
    'quantidadeReloadApertando',
    'quantidadeReloadAuto',
    'distanciaPercorrida']

# %%
def parseiaNivelColuna(dados_json):

    dict_compl =  {}
    
    for nivel in dados_json['niveis']:
        dict_nivel = {}
        id_nivel = str(nivel['ID'])
        usou_cheat = [ nivel['cheat'] ] 
        
        
        
        dict_nivel['usou_cheat_'+ id_nivel] = usou_cheat
        dict_nivel['nota_dificuldade_' + id_nivel] = [nivel['notaDificuldade']]
        dict_nivel['dificuldade_apropriada_' + id_nivel] = [nivel['difuldadeApropriada']]
        dict_nivel['nivelTedioso_' + id_nivel] = [nivel['nivelTedioso']]
        dict_nivel['nivelDivertido_' + id_nivel] = [nivel['nivelDivertido']]
        dict_nivel['nivelFrustrante_' + id_nivel] = [nivel['nivelFrustrante']]
        dict_nivel['tempoTotal_' + id_nivel] = [nivel['tempoTotal']]
        dict_nivel['quantidadeMortes_' + id_nivel ] = [nivel['quantidadeMortes']]
         
        if not usou_cheat:
            #print(str(nivel['cheat']) + id_nivel)
            for column in colunas_nivel:
                #print(nivel['dadosAntesMorrer'][-1][column])
                dict_nivel[column + '_' + 'nvl_' + id_nivel] = [ nivel['dadosAntesMorrer'][-1][column] ]
        else:
            """
            encontra a melhor tentativa , a melhor tentativa foi 
            definida nos casos em que a pessoa não consegue passar
            como aquela em que o jogador conseguiu derrotar o maior número de inimigos.
            """
            
            melhor_tentativa = 0
            melhor_ini_derrotados = 0
            for i,tentativa in enumerate(nivel['dadosAntesMorrer']):
                if (len(tentativa['inimigosDerrotados']) > melhor_ini_derrotados):
                    melhor_ini_derrotados = len(tentativa['inimigosDerrotados'])
                    melhor_tentativa = i

            for column in colunas_nivel:
                dict_nivel[column + '_' + 'nvl_' + id_nivel] = [ nivel['dadosAntesMorrer'][melhor_tentativa][column] ] 

        #print(dict_nivel)
        dict_compl = {**dict_compl , **dict_nivel}

    #print(dict_compl)
    df_nivel = pd.DataFrame(dict_compl)
    
    return df_nivel

# %%
def parserDados(data):
    """ Recebe o json dos dados do teste e cria um dataFrame com todos os dados."""
    df  = []
    data.keys()
    #print ({key : [value] for key,value in (data['questionarioInicial']).items() })
    
    df_quest_inic = pd.DataFrame({'inicial_' + key : [value] for key,value in (data['questionarioInicial']).items() } )
    df_quest_final = pd.DataFrame({'final_' + key : [value] for key,value in (data['questionarioFinal']).items() } )
    df_nivel = parseiaNivelColuna(data)
    
    
    
    
    
    
    df = pd.concat([df_quest_inic, df_quest_final, df_nivel], sort=True, axis=1)
    return df


dados_experimento = []
#print(type(dados_experimento))
for dado in dados:
    df_aux = parserDados(dado)  
    dados_experimento.append(df_aux)
    

df_final = pd.concat(dados_experimento).reset_index(drop=True)

# %%
df_final.head(3)
# Out:
#    inicial_idade inicial_sexo  inicial_q3  inicial_q4  inicial_q5  inicial_q6  \
# 0             25        Homem           3           4           5           3
# 1             26        Homem           1           4           4           4
# 2             28        Homem           5           5           5           5
#
#    inicial_q7 inicial_q8  inicial_q9_a  inicial_q9_b  inicial_q9_c  \
# 0           5      Médio             5             1             1
# 1           3      Fácil             1             1             1
# 2           5      Médio             3             3             3
#
#    inicial_q9_d  final_q1_a  final_q1_b  final_q1_c  final_q1_d  final_q1_e  \
# 0             3       False        True       False       False        True
# 1             2        True       False       False       False        True
# 2             5       False       False       False       False        True
#
#    final_q1_f  final_q2  final_q3_a  final_q3_b  final_q3_c  final_q4_a  \
# 0       False         3           5           5           5           5
# 1       False         3           3           4           5           5
# 2       False         3           5           5           5           3
#
#    final_q4_b  final_q4_c  final_q4_d  final_q4_e  final_q4_f  final_q5_a  \
# 0           2           3           3           3           4           4
# 1           3           5           5           5           5           4
# 2           3           3           1           3           5           3
#
#    final_q5_b  final_q5_c  final_q5_d  final_q5_e  final_q5_f  final_q5_g  \
# 0           3           3           4           3           5           4
# 1           4           4           5           5           5           3
# 2           3           3           3           1           1           5
#
#    final_q5_h  usou_cheat_0  nota_dificuldade_0 dificuldade_apropriada_0  \
# 0           4         False                   0                    Atual
# 1           1         False                   0                    Atual
# 2           5         False                   0                    Atual
#
#    nivelTedioso_0  nivelDivertido_0  nivelFrustrante_0  tempoTotal_0  \
# 0               5                 5                  5     93.462151
# 1               5                 5                  1    102.152779
# 2               5                 5                  5    122.427254
#
#    quantidadeMortes_0  tempoParado_nvl_0  tempoMovimentando_nvl_0  \
# 0                   0          34.294888                59.167294
# 1                   0          29.677563                72.475456
# 2                   0          56.685261                65.742317
#
#    tempoAtirando_nvl_0  tempoRecarregando_nvl_0  tempoSliding_nvl_0  \
# 0             8.501190                 4.985575            5.010180
# 1             6.545364                 3.323567            4.849498
# 2             7.185135                 3.320336            6.995934
#
#    tempoDash_nvl_0  tempoPulando_nvl_0  tempoCaindo_nvl_0  \
# 0         4.062448           16.630804          15.141868
# 1         8.583871           18.413418          18.583275
# 2         9.317859           15.006721          13.920615
#
#    tempoAgachado_nvl_0  quantidadeTiros_nvl_0  quantidadeTirosAcertados_nvl_0  \
# 0             6.403224                     67                              29
# 1             5.127779                     60                              26
# 2             3.840504                     56                              32
#
#    quantidadeTirosAcertadosCausandoDano_nvl_0  \
# 0                                          14
# 1                                          11
# 2                                          17
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_0  quantidadeTirosErrados_nvl_0  \
# 0                                           15                            40
# 1                                           15                            34
# 2                                           15                            25
#
#    quantidadeAgachado_nvl_0  quantidadePulos_nvl_0  quantidadeDash_nvl_0  \
# 0                        15                     66                     9
# 1                        12                     83                    18
# 2                        10                     64                    19
#
#    quantidadeReloadApertando_nvl_0  quantidadeReloadAuto_nvl_0  \
# 0                                2                           1
# 1                                0                           2
# 2                                1                           1
#
#    distanciaPercorrida_nvl_0  usou_cheat_1  nota_dificuldade_1  \
# 0                 346.408264         False                   3
# 1                 385.028992         False                   1
# 2                 370.931458         False                  10
#
#   dificuldade_apropriada_1  nivelTedioso_1  nivelDivertido_1  \
# 0                    Atual               1                 3
# 1                    Atual               5                 1
# 2                    Atual               1                 5
#
#    nivelFrustrante_1  tempoTotal_1  quantidadeMortes_1  tempoParado_nvl_1  \
# 0                  1     16.200323                   0           6.544446
# 1                  1     18.639490                   0           7.039749
# 2                  1     14.819822                   0           6.923502
#
#    tempoMovimentando_nvl_1  tempoAtirando_nvl_1  tempoRecarregando_nvl_1  \
# 0                 9.655874             2.137939                      0.0
# 1                11.599774             1.810695                      0.0
# 2                 7.896342             2.415937                      0.0
#
#    tempoSliding_nvl_1  tempoDash_nvl_1  tempoPulando_nvl_1  tempoCaindo_nvl_1  \
# 0            0.097766         0.399975            0.720625           1.981666
# 1            0.498096         0.000000            0.699141           1.982017
# 2            0.459658         0.000000            0.618632           1.499451
#
#    tempoAgachado_nvl_1  quantidadeTiros_nvl_1  quantidadeTirosAcertados_nvl_1  \
# 0             1.504293                     17                              24
# 1             3.739581                     14                              14
# 2             0.220534                     18                              28
#
#    quantidadeTirosAcertadosCausandoDano_nvl_1  \
# 0                                          17
# 1                                           9
# 2                                          21
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_1  quantidadeTirosErrados_nvl_1  \
# 0                                            7                             3
# 1                                            5                             5
# 2                                            7                             4
#
#    quantidadeAgachado_nvl_1  quantidadePulos_nvl_1  quantidadeDash_nvl_1  \
# 0                         4                      5                     1
# 1                         7                      6                     0
# 2                         2                      4                     0
#
#    quantidadeReloadApertando_nvl_1  quantidadeReloadAuto_nvl_1  \
# 0                                0                           0
# 1                                0                           0
# 2                                0                           0
#
#    distanciaPercorrida_nvl_1  usou_cheat_2  nota_dificuldade_2  \
# 0                  67.317131         False                   4
# 1                  76.549294         False                   2
# 2                  50.551338         False                   1
#
#   dificuldade_apropriada_2  nivelTedioso_2  nivelDivertido_2  \
# 0                    Atual               1                 4
# 1                    Atual               3                 3
# 2                    Atual               1                 5
#
#    nivelFrustrante_2  tempoTotal_2  quantidadeMortes_2  tempoParado_nvl_2  \
# 0                  1     26.799795                   0          11.716894
# 1                  3     40.921124                   1          14.706940
# 2                  1     16.661375                   0           5.941116
#
#    tempoMovimentando_nvl_2  tempoAtirando_nvl_2  tempoRecarregando_nvl_2  \
# 0                15.082877             1.798150                 1.660474
# 1                10.553313             6.815266                 1.660874
# 2                10.720304             1.884401                 0.000000
#
#    tempoSliding_nvl_2  tempoDash_nvl_2  tempoPulando_nvl_2  tempoCaindo_nvl_2  \
# 0            1.320709         0.938901            3.275110           3.842243
# 1            0.840479         0.000000            1.619256           2.658261
# 2            1.738619         0.499676            2.101320           2.520844
#
#    tempoAgachado_nvl_2  quantidadeTiros_nvl_2  quantidadeTirosAcertados_nvl_2  \
# 0             0.000000                     14                              13
# 1             9.403452                     54                              32
# 2             0.000000                     15                              24
#
#    quantidadeTirosAcertadosCausandoDano_nvl_2  \
# 0                                           8
# 1                                          19
# 2                                          16
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_2  quantidadeTirosErrados_nvl_2  \
# 0                                            5                             4
# 1                                           13                            36
# 2                                            8                             3
#
#    quantidadeAgachado_nvl_2  quantidadePulos_nvl_2  quantidadeDash_nvl_2  \
# 0                         0                     15                     2
# 1                         5                      8                     0
# 2                         0                      9                     1
#
#    quantidadeReloadApertando_nvl_2  quantidadeReloadAuto_nvl_2  \
# 0                                1                           0
# 1                                0                           1
# 2                                0                           0
#
#    distanciaPercorrida_nvl_2  usou_cheat_3  nota_dificuldade_3  \
# 0                  69.179390         False                   4
# 1                  52.460800         False                   2
# 2                  48.639904         False                   5
#
#   dificuldade_apropriada_3  nivelTedioso_3  nivelDivertido_3  \
# 0                    Atual               1                 5
# 1                    Atual               3                 3
# 2                    Atual               1                 5
#
#    nivelFrustrante_3  tempoTotal_3  quantidadeMortes_3  tempoParado_nvl_3  \
# 0                  1     19.240860                   0           7.374172
# 1                  3     26.859015                   0          13.649595
# 2                  1     16.099522                   0           7.054205
#
#    tempoMovimentando_nvl_3  tempoAtirando_nvl_3  tempoRecarregando_nvl_3  \
# 0                11.866674             6.200827                 1.662609
# 1                13.209464             7.576593                 1.660901
# 2                 9.045318             6.624248                 1.660865
#
#    tempoSliding_nvl_3  tempoDash_nvl_3  tempoPulando_nvl_3  tempoCaindo_nvl_3  \
# 0            0.000000         0.000000            1.678014           2.780616
# 1            0.200435         1.000352            1.018628           1.995851
# 2            0.000000         0.000000            0.500898           1.358102
#
#    tempoAgachado_nvl_3  quantidadeTiros_nvl_3  quantidadeTirosAcertados_nvl_3  \
# 0             0.618745                     48                              42
# 1             2.859021                     58                              34
# 2             0.200045                     50                              45
#
#    quantidadeTirosAcertadosCausandoDano_nvl_3  \
# 0                                          23
# 1                                          16
# 2                                          26
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_3  quantidadeTirosErrados_nvl_3  \
# 0                                           19                            21
# 1                                           18                            28
# 2                                           19                            20
#
#    quantidadeAgachado_nvl_3  quantidadePulos_nvl_3  quantidadeDash_nvl_3  \
# 0                         2                      6                     0
# 1                         6                      5                     2
# 2                         1                      2                     0
#
#    quantidadeReloadApertando_nvl_3  quantidadeReloadAuto_nvl_3  \
# 0                                0                           1
# 1                                0                           1
# 2                                0                           1
#
#    distanciaPercorrida_nvl_3  usou_cheat_4  nota_dificuldade_4  \
# 0                  72.332191         False                   6
# 1                  56.625881         False                   6
# 2                  55.356792         False                   5
#
#   dificuldade_apropriada_4  nivelTedioso_4  nivelDivertido_4  \
# 0                    Atual               1                 5
# 1                    Atual               1                 4
# 2                    Atual               1                 5
#
#    nivelFrustrante_4  tempoTotal_4  quantidadeMortes_4  tempoParado_nvl_4  \
# 0                  1    164.499222                   2          31.486252
# 1                  1    281.160706                   3          55.472759
# 2                  1    186.438065                   2          37.234341
#
#    tempoMovimentando_nvl_4  tempoAtirando_nvl_4  tempoRecarregando_nvl_4  \
# 0                33.051987            17.787283                 8.306043
# 1                54.966011            21.609703                 8.304194
# 2                43.145050            18.364941                 6.648398
#
#    tempoSliding_nvl_4  tempoDash_nvl_4  tempoPulando_nvl_4  tempoCaindo_nvl_4  \
# 0            4.620195              0.0            7.935434           9.657242
# 1            5.362276              0.0           17.991793          18.462780
# 2            3.501424              0.0            8.424376          11.426557
#
#    tempoAgachado_nvl_4  quantidadeTiros_nvl_4  quantidadeTirosAcertados_nvl_4  \
# 0             0.000000                    135                             150
# 1             0.061088                    170                             151
# 2             0.000000                    141                             173
#
#    quantidadeTirosAcertadosCausandoDano_nvl_4  \
# 0                                          94
# 1                                          97
# 2                                         118
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_4  quantidadeTirosErrados_nvl_4  \
# 0                                           56                            34
# 1                                           54                            83
# 2                                           55                            40
#
#    quantidadeAgachado_nvl_4  quantidadePulos_nvl_4  quantidadeDash_nvl_4  \
# 0                         0                     33                     0
# 1                         1                     84                     0
# 2                         0                     30                     0
#
#    quantidadeReloadApertando_nvl_4  quantidadeReloadAuto_nvl_4  \
# 0                                3                           2
# 1                                0                           5
# 2                                0                           4
#
#    distanciaPercorrida_nvl_4  usou_cheat_5  nota_dificuldade_5  \
# 0                 122.454514         False                   4
# 1                 235.514191         False                   6
# 2                 211.277985         False                   1
#
#   dificuldade_apropriada_5  nivelTedioso_5  nivelDivertido_5  \
# 0                    Atual               1                 5
# 1                 Anterior               2                 4
# 2                    Atual               1                 5
#
#    nivelFrustrante_5  tempoTotal_5  quantidadeMortes_5  tempoParado_nvl_5  \
# 0                  1     62.240868                   0          40.709312
# 1                  3    145.799652                   1          32.492184
# 2                  1     96.580276                   0          55.908211
#
#    tempoMovimentando_nvl_5  tempoAtirando_nvl_5  tempoRecarregando_nvl_5  \
# 0                21.531443            23.494858                13.291907
# 1                24.027960            20.352627                 8.307724
# 2                40.671562            29.318340                11.629234
#
#    tempoSliding_nvl_5  tempoDash_nvl_5  tempoPulando_nvl_5  tempoCaindo_nvl_5  \
# 0            0.881030         3.497170            2.705389           2.695151
# 1            1.821679         0.000000            4.877219           5.705029
# 2            0.920432         3.000858            7.725172           8.279335
#
#    tempoAgachado_nvl_5  quantidadeTiros_nvl_5  quantidadeTirosAcertados_nvl_5  \
# 0             0.000000                    179                             201
# 1             0.397543                    154                             173
# 2             0.000000                    226                             174
#
#    quantidadeTirosAcertadosCausandoDano_nvl_5  \
# 0                                         132
# 1                                         108
# 2                                         103
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_5  quantidadeTirosErrados_nvl_5  \
# 0                                           69                            53
# 1                                           65                            40
# 2                                           71                           101
#
#    quantidadeAgachado_nvl_5  quantidadePulos_nvl_5  quantidadeDash_nvl_5  \
# 0                         0                     13                     7
# 1                         1                     22                     0
# 2                         0                     26                     6
#
#    quantidadeReloadApertando_nvl_5  quantidadeReloadAuto_nvl_5  \
# 0                                4                           4
# 1                                1                           4
# 2                                0                           7
#
#    distanciaPercorrida_nvl_5  usou_cheat_6  nota_dificuldade_6  \
# 0                 130.579376         False                   8
# 1                 117.312874         False                   8
# 2                 219.262497         False                   5
#
#   dificuldade_apropriada_6  nivelTedioso_6  nivelDivertido_6  \
# 0                    Atual               1                 3
# 1                    Atual               1                 4
# 2                    Atual               1                 5
#
#    nivelFrustrante_6  tempoTotal_6  quantidadeMortes_6  tempoParado_nvl_6  \
# 0                  2    506.000061                  10          63.495983
# 1                  1    438.696411                   4          86.292198
# 2                  1    241.640778                   4          54.708839
#
#    tempoMovimentando_nvl_6  tempoAtirando_nvl_6  tempoRecarregando_nvl_6  \
# 0                32.464928            29.077753                18.271547
# 1                35.771011            36.693630                18.273447
# 2                35.331200            38.811573                14.952486
#
#    tempoSliding_nvl_6  tempoDash_nvl_6  tempoPulando_nvl_6  tempoCaindo_nvl_6  \
# 0            4.889190         1.001958            7.312923           7.821317
# 1            5.731941         0.000000            8.561917           8.463820
# 2            2.538150         2.901012            7.500140           7.904083
#
#    tempoAgachado_nvl_6  quantidadeTiros_nvl_6  quantidadeTirosAcertados_nvl_6  \
# 0            21.506824                    215                             195
# 1            34.956520                    274                             180
# 2             1.215093                    290                             208
#
#    quantidadeTirosAcertadosCausandoDano_nvl_6  \
# 0                                         115
# 1                                          99
# 2                                         130
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_6  quantidadeTirosErrados_nvl_6  \
# 0                                           80                            69
# 1                                           81                           134
# 2                                           78                           156
#
#    quantidadeAgachado_nvl_6  quantidadePulos_nvl_6  quantidadeDash_nvl_6  \
# 0                        17                     41                     2
# 1                        12                     45                     0
# 2                         4                     29                     6
#
#    quantidadeReloadApertando_nvl_6  quantidadeReloadAuto_nvl_6  \
# 0                                9                           2
# 1                                7                           4
# 2                                0                           9
#
#    distanciaPercorrida_nvl_6  usou_cheat_7  nota_dificuldade_7  \
# 0                 171.234894         False                   7
# 1                 199.327255          True                  10
# 2                 176.205643         False                   5
#
#   dificuldade_apropriada_7  nivelTedioso_7  nivelDivertido_7  \
# 0                 Anterior               1                 4
# 1                 Anterior               5                 1
# 2                    Atual               1                 5
#
#    nivelFrustrante_7  tempoTotal_7  quantidadeMortes_7  tempoParado_nvl_7  \
# 0                  1    297.259064                   5          37.389194
# 1                  1    640.281128                  16          39.773174
# 2                  1     75.197716                   0          41.914013
#
#    tempoMovimentando_nvl_7  tempoAtirando_nvl_7  tempoRecarregando_nvl_7  \
# 0                31.709278            23.296810                18.099680
# 1                16.607674            16.155022                 9.970927
# 2                33.283871            19.439085                 8.306254
#
#    tempoSliding_nvl_7  tempoDash_nvl_7  tempoPulando_nvl_7  tempoCaindo_nvl_7  \
# 0            4.720007         1.781563            6.441097           5.777568
# 1            2.298935         0.499958            2.400621           2.899664
# 2            3.702274         3.003319            7.361062           7.236584
#
#    tempoAgachado_nvl_7  quantidadeTiros_nvl_7  quantidadeTirosAcertados_nvl_7  \
# 0             7.418060                    174                              87
# 1             7.161475                    123                              80
# 2             1.019780                    150                             151
#
#    quantidadeTirosAcertadosCausandoDano_nvl_7  \
# 0                                          48
# 1                                          54
# 2                                         106
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_7  quantidadeTirosErrados_nvl_7  \
# 0                                           39                           117
# 1                                           26                            79
# 2                                           45                            63
#
#    quantidadeAgachado_nvl_7  quantidadePulos_nvl_7  quantidadeDash_nvl_7  \
# 0                         7                     28                     4
# 1                         2                     11                     1
# 2                         3                     26                     6
#
#    quantidadeReloadApertando_nvl_7  quantidadeReloadAuto_nvl_7  \
# 0                               11                           0
# 1                                4                           2
# 2                                0                           5
#
#    distanciaPercorrida_nvl_7  usou_cheat_8  nota_dificuldade_8  \
# 0                 155.502991          True                  10
# 1                  73.875443          True                  10
# 2                 157.170303         False                  10
#
#   dificuldade_apropriada_8  nivelTedioso_8  nivelDivertido_8  \
# 0                    Atual               1                 5
# 1                    Atual               5                 4
# 2                    Atual               1                 5
#
#    nivelFrustrante_8  tempoTotal_8  quantidadeMortes_8  tempoParado_nvl_8  \
# 0                  1    572.084595                   8         121.148346
# 1                  1    677.281067                   7          92.670250
# 2                  1    642.644287                   6         115.821747
#
#    tempoMovimentando_nvl_8  tempoAtirando_nvl_8  tempoRecarregando_nvl_8  \
# 0               102.512032            60.138657                49.847492
# 1                81.230156            35.627228                26.597509
# 2               133.878860            82.158432                33.230091
#
#    tempoSliding_nvl_8  tempoDash_nvl_8  tempoPulando_nvl_8  tempoCaindo_nvl_8  \
# 0           12.894499         1.003469           21.158476          24.726557
# 1           13.406945         1.299191           14.833691          15.863751
# 2            9.428349         5.995975           24.561670          27.912132
#
#    tempoAgachado_nvl_8  quantidadeTiros_nvl_8  quantidadeTirosAcertados_nvl_8  \
# 0            54.640511                    455                             501
# 1            28.211805                    275                             221
# 2             0.339067                    624                             555
#
#    quantidadeTirosAcertadosCausandoDano_nvl_8  \
# 0                                         310
# 1                                         141
# 2                                         353
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_8  quantidadeTirosErrados_nvl_8  \
# 0                                          191                           103
# 1                                           80                           123
# 2                                          202                           259
#
#    quantidadeAgachado_nvl_8  quantidadePulos_nvl_8  quantidadeDash_nvl_8  \
# 0                        33                    105                     2
# 1                        17                     68                     3
# 2                         1                     86                    12
#
#    quantidadeReloadApertando_nvl_8  quantidadeReloadAuto_nvl_8  \
# 0                               27                           3
# 1                               13                           3
# 2                                0                          20
#
#    distanciaPercorrida_nvl_8
# 0                 495.977753
# 1                 346.150970
# 2                 676.410156

# %%
def pegaColunas(data, query):
    'retorna colunas com base em uma query'
    columns = [x for x in data.columns if query in x]
    
    values = data[columns]
    
    return values

# %%
teste = pegaColunas(df_final, 'nota_dificuldade')


teste.mean().plot(kind='bar')
plt.title('Média dificuldade x Nível')
# Out:
# Text(0.5, 1.0, 'Média dificuldade x Nível')

# %%
#Gerar gráfico de barrars nível x [tédio, diversão , frustração]

ted_col = pegaColunas(df_final, 'nivelTedioso')
div_col = pegaColunas(df_final, 'nivelDivertido')
frus_col = pegaColunas(df_final, 'nivelFrustrante')
#(ted.mean().values,div.mean().values,frus.mean().values)
#to-do, continuar desenvolvendo este gráfico.
#plt.figure(figsize=(20,20))
#pd.concat([ted,div,frus],axis=1).plot(kind='bar',)

ted = ted_col.mean().values[1:]
div = div_col.mean().values[1:]
frus = frus_col.mean().values[1:]

ted_error = ted_col.std().values[1:]
div_error = div_col.std().values[1:]
frus_error = frus_col.std().values[1:]

n_groups = 9

fig,ax = plt.subplots(figsize=(12, 7))
index = np.arange(n_groups)[1:]
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index + 0.12, ted , bar_width * 0.5 , alpha = opacity, color = 'b', label = 'Tédio', yerr = ted_error, capsize=5)

rects2 = plt.bar(index + bar_width  , div, bar_width * 0.5 , alpha = opacity , color='g', label = 'Diversão', yerr = div_error, capsize=5 )

rects3 = plt.bar(index  + bar_width * 2 - 0.12 , frus , bar_width  * 0.5 , alpha = opacity, color = 'r' , label = 'Frustração', yerr = frus_error, capsize=5)


plt.xlabel('Níveis')
plt.ylabel('Critério')
plt.title('Opinião por nível')
plt.xticks(index +  bar_width, (index))
plt.legend()
#fig.figure(figsize=(20,20))
#plt.tight_layout()
fig.savefig('OpiniaoXNivel.png')

# %%
def plotaColunaCheat(data, query):
    'retorna colunas com base em uma query'
    columns = [x for x in data.columns if query in x]
    
    values = data[columns]
    
    return values

# %%
#teste.mean() 
x  = [ i for i in range (0,9)]


plt.bar(x[1:],teste.mean().values[1:]  )
# Out:
# <BarContainer object of 8 artists>

# %%
teste = pegaColunas(df_final , 'nota_dificuldade')

plt.title('Média dificuldade x Densidade') 

x  = [ i for i in range (0,9)]


sns.lineplot(x[1:], teste.mean().values[1:] , marker='o')
plt.errorbar(x[1:], teste.mean().values[1:], yerr=teste.std()[1:], fmt='.k',);
plt.figure(figsize=(5,10))

# %%
df_final.head(1)
# Out:
#    inicial_idade inicial_sexo  inicial_q3  inicial_q4  inicial_q5  inicial_q6  \
# 0             25        Homem           3           4           5           3
#
#    inicial_q7 inicial_q8  inicial_q9_a  inicial_q9_b  inicial_q9_c  \
# 0           5      Médio             5             1             1
#
#    inicial_q9_d  final_q1_a  final_q1_b  final_q1_c  final_q1_d  final_q1_e  \
# 0             3       False        True       False       False        True
#
#    final_q1_f  final_q2  final_q3_a  final_q3_b  final_q3_c  final_q4_a  \
# 0       False         3           5           5           5           5
#
#    final_q4_b  final_q4_c  final_q4_d  final_q4_e  final_q4_f  final_q5_a  \
# 0           2           3           3           3           4           4
#
#    final_q5_b  final_q5_c  final_q5_d  final_q5_e  final_q5_f  final_q5_g  \
# 0           3           3           4           3           5           4
#
#    final_q5_h  usou_cheat_0  nota_dificuldade_0 dificuldade_apropriada_0  \
# 0           4         False                   0                    Atual
#
#    nivelTedioso_0  nivelDivertido_0  nivelFrustrante_0  tempoTotal_0  \
# 0               5                 5                  5     93.462151
#
#    quantidadeMortes_0  tempoParado_nvl_0  tempoMovimentando_nvl_0  \
# 0                   0          34.294888                59.167294
#
#    tempoAtirando_nvl_0  tempoRecarregando_nvl_0  tempoSliding_nvl_0  \
# 0              8.50119                 4.985575             5.01018
#
#    tempoDash_nvl_0  tempoPulando_nvl_0  tempoCaindo_nvl_0  \
# 0         4.062448           16.630804          15.141868
#
#    tempoAgachado_nvl_0  quantidadeTiros_nvl_0  quantidadeTirosAcertados_nvl_0  \
# 0             6.403224                     67                              29
#
#    quantidadeTirosAcertadosCausandoDano_nvl_0  \
# 0                                          14
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_0  quantidadeTirosErrados_nvl_0  \
# 0                                           15                            40
#
#    quantidadeAgachado_nvl_0  quantidadePulos_nvl_0  quantidadeDash_nvl_0  \
# 0                        15                     66                     9
#
#    quantidadeReloadApertando_nvl_0  quantidadeReloadAuto_nvl_0  \
# 0                                2                           1
#
#    distanciaPercorrida_nvl_0  usou_cheat_1  nota_dificuldade_1  \
# 0                 346.408264         False                   3
#
#   dificuldade_apropriada_1  nivelTedioso_1  nivelDivertido_1  \
# 0                    Atual               1                 3
#
#    nivelFrustrante_1  tempoTotal_1  quantidadeMortes_1  tempoParado_nvl_1  \
# 0                  1     16.200323                   0           6.544446
#
#    tempoMovimentando_nvl_1  tempoAtirando_nvl_1  tempoRecarregando_nvl_1  \
# 0                 9.655874             2.137939                      0.0
#
#    tempoSliding_nvl_1  tempoDash_nvl_1  tempoPulando_nvl_1  tempoCaindo_nvl_1  \
# 0            0.097766         0.399975            0.720625           1.981666
#
#    tempoAgachado_nvl_1  quantidadeTiros_nvl_1  quantidadeTirosAcertados_nvl_1  \
# 0             1.504293                     17                              24
#
#    quantidadeTirosAcertadosCausandoDano_nvl_1  \
# 0                                          17
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_1  quantidadeTirosErrados_nvl_1  \
# 0                                            7                             3
#
#    quantidadeAgachado_nvl_1  quantidadePulos_nvl_1  quantidadeDash_nvl_1  \
# 0                         4                      5                     1
#
#    quantidadeReloadApertando_nvl_1  quantidadeReloadAuto_nvl_1  \
# 0                                0                           0
#
#    distanciaPercorrida_nvl_1  usou_cheat_2  nota_dificuldade_2  \
# 0                  67.317131         False                   4
#
#   dificuldade_apropriada_2  nivelTedioso_2  nivelDivertido_2  \
# 0                    Atual               1                 4
#
#    nivelFrustrante_2  tempoTotal_2  quantidadeMortes_2  tempoParado_nvl_2  \
# 0                  1     26.799795                   0          11.716894
#
#    tempoMovimentando_nvl_2  tempoAtirando_nvl_2  tempoRecarregando_nvl_2  \
# 0                15.082877              1.79815                 1.660474
#
#    tempoSliding_nvl_2  tempoDash_nvl_2  tempoPulando_nvl_2  tempoCaindo_nvl_2  \
# 0            1.320709         0.938901             3.27511           3.842243
#
#    tempoAgachado_nvl_2  quantidadeTiros_nvl_2  quantidadeTirosAcertados_nvl_2  \
# 0                  0.0                     14                              13
#
#    quantidadeTirosAcertadosCausandoDano_nvl_2  \
# 0                                           8
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_2  quantidadeTirosErrados_nvl_2  \
# 0                                            5                             4
#
#    quantidadeAgachado_nvl_2  quantidadePulos_nvl_2  quantidadeDash_nvl_2  \
# 0                         0                     15                     2
#
#    quantidadeReloadApertando_nvl_2  quantidadeReloadAuto_nvl_2  \
# 0                                1                           0
#
#    distanciaPercorrida_nvl_2  usou_cheat_3  nota_dificuldade_3  \
# 0                   69.17939         False                   4
#
#   dificuldade_apropriada_3  nivelTedioso_3  nivelDivertido_3  \
# 0                    Atual               1                 5
#
#    nivelFrustrante_3  tempoTotal_3  quantidadeMortes_3  tempoParado_nvl_3  \
# 0                  1      19.24086                   0           7.374172
#
#    tempoMovimentando_nvl_3  tempoAtirando_nvl_3  tempoRecarregando_nvl_3  \
# 0                11.866674             6.200827                 1.662609
#
#    tempoSliding_nvl_3  tempoDash_nvl_3  tempoPulando_nvl_3  tempoCaindo_nvl_3  \
# 0                 0.0              0.0            1.678014           2.780616
#
#    tempoAgachado_nvl_3  quantidadeTiros_nvl_3  quantidadeTirosAcertados_nvl_3  \
# 0             0.618745                     48                              42
#
#    quantidadeTirosAcertadosCausandoDano_nvl_3  \
# 0                                          23
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_3  quantidadeTirosErrados_nvl_3  \
# 0                                           19                            21
#
#    quantidadeAgachado_nvl_3  quantidadePulos_nvl_3  quantidadeDash_nvl_3  \
# 0                         2                      6                     0
#
#    quantidadeReloadApertando_nvl_3  quantidadeReloadAuto_nvl_3  \
# 0                                0                           1
#
#    distanciaPercorrida_nvl_3  usou_cheat_4  nota_dificuldade_4  \
# 0                  72.332191         False                   6
#
#   dificuldade_apropriada_4  nivelTedioso_4  nivelDivertido_4  \
# 0                    Atual               1                 5
#
#    nivelFrustrante_4  tempoTotal_4  quantidadeMortes_4  tempoParado_nvl_4  \
# 0                  1    164.499222                   2          31.486252
#
#    tempoMovimentando_nvl_4  tempoAtirando_nvl_4  tempoRecarregando_nvl_4  \
# 0                33.051987            17.787283                 8.306043
#
#    tempoSliding_nvl_4  tempoDash_nvl_4  tempoPulando_nvl_4  tempoCaindo_nvl_4  \
# 0            4.620195              0.0            7.935434           9.657242
#
#    tempoAgachado_nvl_4  quantidadeTiros_nvl_4  quantidadeTirosAcertados_nvl_4  \
# 0                  0.0                    135                             150
#
#    quantidadeTirosAcertadosCausandoDano_nvl_4  \
# 0                                          94
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_4  quantidadeTirosErrados_nvl_4  \
# 0                                           56                            34
#
#    quantidadeAgachado_nvl_4  quantidadePulos_nvl_4  quantidadeDash_nvl_4  \
# 0                         0                     33                     0
#
#    quantidadeReloadApertando_nvl_4  quantidadeReloadAuto_nvl_4  \
# 0                                3                           2
#
#    distanciaPercorrida_nvl_4  usou_cheat_5  nota_dificuldade_5  \
# 0                 122.454514         False                   4
#
#   dificuldade_apropriada_5  nivelTedioso_5  nivelDivertido_5  \
# 0                    Atual               1                 5
#
#    nivelFrustrante_5  tempoTotal_5  quantidadeMortes_5  tempoParado_nvl_5  \
# 0                  1     62.240868                   0          40.709312
#
#    tempoMovimentando_nvl_5  tempoAtirando_nvl_5  tempoRecarregando_nvl_5  \
# 0                21.531443            23.494858                13.291907
#
#    tempoSliding_nvl_5  tempoDash_nvl_5  tempoPulando_nvl_5  tempoCaindo_nvl_5  \
# 0             0.88103          3.49717            2.705389           2.695151
#
#    tempoAgachado_nvl_5  quantidadeTiros_nvl_5  quantidadeTirosAcertados_nvl_5  \
# 0                  0.0                    179                             201
#
#    quantidadeTirosAcertadosCausandoDano_nvl_5  \
# 0                                         132
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_5  quantidadeTirosErrados_nvl_5  \
# 0                                           69                            53
#
#    quantidadeAgachado_nvl_5  quantidadePulos_nvl_5  quantidadeDash_nvl_5  \
# 0                         0                     13                     7
#
#    quantidadeReloadApertando_nvl_5  quantidadeReloadAuto_nvl_5  \
# 0                                4                           4
#
#    distanciaPercorrida_nvl_5  usou_cheat_6  nota_dificuldade_6  \
# 0                 130.579376         False                   8
#
#   dificuldade_apropriada_6  nivelTedioso_6  nivelDivertido_6  \
# 0                    Atual               1                 3
#
#    nivelFrustrante_6  tempoTotal_6  quantidadeMortes_6  tempoParado_nvl_6  \
# 0                  2    506.000061                  10          63.495983
#
#    tempoMovimentando_nvl_6  tempoAtirando_nvl_6  tempoRecarregando_nvl_6  \
# 0                32.464928            29.077753                18.271547
#
#    tempoSliding_nvl_6  tempoDash_nvl_6  tempoPulando_nvl_6  tempoCaindo_nvl_6  \
# 0             4.88919         1.001958            7.312923           7.821317
#
#    tempoAgachado_nvl_6  quantidadeTiros_nvl_6  quantidadeTirosAcertados_nvl_6  \
# 0            21.506824                    215                             195
#
#    quantidadeTirosAcertadosCausandoDano_nvl_6  \
# 0                                         115
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_6  quantidadeTirosErrados_nvl_6  \
# 0                                           80                            69
#
#    quantidadeAgachado_nvl_6  quantidadePulos_nvl_6  quantidadeDash_nvl_6  \
# 0                        17                     41                     2
#
#    quantidadeReloadApertando_nvl_6  quantidadeReloadAuto_nvl_6  \
# 0                                9                           2
#
#    distanciaPercorrida_nvl_6  usou_cheat_7  nota_dificuldade_7  \
# 0                 171.234894         False                   7
#
#   dificuldade_apropriada_7  nivelTedioso_7  nivelDivertido_7  \
# 0                 Anterior               1                 4
#
#    nivelFrustrante_7  tempoTotal_7  quantidadeMortes_7  tempoParado_nvl_7  \
# 0                  1    297.259064                   5          37.389194
#
#    tempoMovimentando_nvl_7  tempoAtirando_nvl_7  tempoRecarregando_nvl_7  \
# 0                31.709278             23.29681                 18.09968
#
#    tempoSliding_nvl_7  tempoDash_nvl_7  tempoPulando_nvl_7  tempoCaindo_nvl_7  \
# 0            4.720007         1.781563            6.441097           5.777568
#
#    tempoAgachado_nvl_7  quantidadeTiros_nvl_7  quantidadeTirosAcertados_nvl_7  \
# 0              7.41806                    174                              87
#
#    quantidadeTirosAcertadosCausandoDano_nvl_7  \
# 0                                          48
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_7  quantidadeTirosErrados_nvl_7  \
# 0                                           39                           117
#
#    quantidadeAgachado_nvl_7  quantidadePulos_nvl_7  quantidadeDash_nvl_7  \
# 0                         7                     28                     4
#
#    quantidadeReloadApertando_nvl_7  quantidadeReloadAuto_nvl_7  \
# 0                               11                           0
#
#    distanciaPercorrida_nvl_7  usou_cheat_8  nota_dificuldade_8  \
# 0                 155.502991          True                  10
#
#   dificuldade_apropriada_8  nivelTedioso_8  nivelDivertido_8  \
# 0                    Atual               1                 5
#
#    nivelFrustrante_8  tempoTotal_8  quantidadeMortes_8  tempoParado_nvl_8  \
# 0                  1    572.084595                   8         121.148346
#
#    tempoMovimentando_nvl_8  tempoAtirando_nvl_8  tempoRecarregando_nvl_8  \
# 0               102.512032            60.138657                49.847492
#
#    tempoSliding_nvl_8  tempoDash_nvl_8  tempoPulando_nvl_8  tempoCaindo_nvl_8  \
# 0           12.894499         1.003469           21.158476          24.726557
#
#    tempoAgachado_nvl_8  quantidadeTiros_nvl_8  quantidadeTirosAcertados_nvl_8  \
# 0            54.640511                    455                             501
#
#    quantidadeTirosAcertadosCausandoDano_nvl_8  \
# 0                                         310
#
#    quantidadeTirosAcertadosSemCausarDano_nvl_8  quantidadeTirosErrados_nvl_8  \
# 0                                          191                           103
#
#    quantidadeAgachado_nvl_8  quantidadePulos_nvl_8  quantidadeDash_nvl_8  \
# 0                        33                    105                     2
#
#    quantidadeReloadApertando_nvl_8  quantidadeReloadAuto_nvl_8  \
# 0                               27                           3
#
#    distanciaPercorrida_nvl_8
# 0                 495.977753

# %%
dash_col.mean()
dash_col.std()
# Out:
# quantidadeDash_nvl_0    3.634629
# quantidadeDash_nvl_1    1.508262
# quantidadeDash_nvl_2    0.994135
# quantidadeDash_nvl_3    1.880960
# quantidadeDash_nvl_4    2.139848
# quantidadeDash_nvl_5    2.963718
# quantidadeDash_nvl_6    4.694155
# quantidadeDash_nvl_7    2.181796
# quantidadeDash_nvl_8    3.436134
# dtype: float64

# %% [markdown]
# # A partir desta parte geram os gráficos da análise:
# # to-do : implementar filtro antes deta parte.
#  ### df_final = df_final[ df_final.usou_cheat0 == True & ... ]

# %%
#df_final = df_final[ df_final.usou_cheat0 == True & ... ]

# %%
#Gerar gráfico de quantidade de dashs por nível

dash_col = pegaColunas(df_final, 'quantidadeDash')
dash = dash_col.mean().values[1:]
dash_error = dash_col.std().values[1:]

n_groups = 9

fig,ax = plt.subplots(figsize=(12, 7))
index = np.arange(n_groups)[1:]
bar_width = 0.80
opacity = 0.8
sns.set_style("whitegrid")
rects1 = plt.bar(index , dash , bar_width  , alpha = opacity, color = 'b', yerr = dash_error)

plt.xlabel('Níveis')
plt.ylabel('Quantidade de Dashs')
plt.title('Quantidade de Dashs x Nível')
plt.xticks(index , (index))
plt.legend()
#fig.figure(figsize=(20,20))
#plt.tight_layout()
fig.savefig('qtdDashs_nivel.png')
# Out:
# No handles with labels found to put in legend.

# %%
#Gerar gráfico de quantidade de reloads por nível

rel_manual_col = pegaColunas(df_final, 'quantidadeReloadApertando')
rel_auto_col = pegaColunas(df_final, 'quantidadeReloadAuto')

rel_manual_mean = rel_manual_col.mean().values[1:]
rel_manual_std = rel_manual_col.std().values[1:]

rel_auto_mean = rel_auto_col.mean().values[1:]
rel_auto_std = rel_auto_col.std().values[1:]

n_groups = 9

fig,ax = plt.subplots(figsize=(10, 5))
index = np.arange(n_groups)[1:]
bar_width = 0.35
opacity = 0.8
sns.set_style("whitegrid")

rects1 = plt.bar(index  , rel_manual_mean , bar_width * 0.5 , alpha = opacity, color = 'b', label = 'Reload Manual' , yerr = rel_manual_std)
rects2 = plt.bar(index  + bar_width , rel_auto_mean , bar_width * 0.5 , alpha = opacity,label = 'Reload Automático', color = 'r', yerr = rel_auto_std)
plt.xlabel('Níveis')
plt.ylabel('Reload')
plt.title('Reload x Nível')
plt.xticks(index + 0.15 , (index))
plt.legend()
#fig.figure(figsize=(20,20))
#plt.tight_layout()
fig.savefig('qtd_reloadsXnivel.png')

# %%
#Gerar gráfico de nivel x tempo medio total

tempo_total_col = pegaColunas(df_final, 'tempoTotal_')
tempo_total_mean = tempo_total_col.mean().values[1:]
tempo_total_std = tempo_total_col.std().values[1:]

n_groups = 9

fig,ax = plt.subplots(figsize=(10, 5))
index = np.arange(n_groups)[1:]
bar_width = 0.35
opacity = 0.8
sns.set_style("whitegrid")

rects1 = plt.bar(index  , tempo_total_mean , bar_width  , alpha = opacity, color = 'b', yerr = tempo_total_std)
plt.xlabel('Níveis')
plt.ylabel('Tempo Total')
plt.title('Tempo Total x Nível')
plt.xticks(index , (index))
plt.legend()
#fig.figure(figsize=(20,20))
#plt.tight_layout()
fig.savefig('tempoTotalXnivel.png')
# Out:
# No handles with labels found to put in legend.

# %%
#Gerar gráfico de quantidade de reloads por nível

tiros_acer = pegaColunas(df_final, 'quantidadeTirosAcertadosCausandoDano')
tiros_err = pegaColunas(df_final, 'quantidadeTirosAcertadosSemCausarDano')

tiros_acer_mean = tiros_acer.mean().values[1:]
tiros_acer_std = tiros_acer.std().values[1:]

tiros_err_mean = tiros_err.mean().values[1:]
tiros_err_std = tiros_err.std().values[1:]

n_groups = 9

fig,ax = plt.subplots(figsize=(10, 5))
index = np.arange(n_groups)[1:]
bar_width = 0.35
opacity = 0.8
sns.set_style("whitegrid")

rects1 = plt.bar(index  , tiros_acer_mean , bar_width * 0.5 , alpha = opacity, color = 'b', label = 'Reload Manual' , yerr = tiros_acer_std)
rects2 = plt.bar(index  + bar_width , tiros_err_mean , bar_width * 0.5 , alpha = opacity,label = 'Reload Automático', color = 'r', yerr = tiros_err_std)
plt.xlabel('Níveis')
plt.ylabel('Tiros')
plt.title('Tiros x Nível')
plt.xticks(index + 0.15 , (index))
plt.legend()
#fig.figure(figsize=(20,20))
#plt.tight_layout()
fig.savefig('tirosAcerErroXnivel.png')

# %%
#nivel x de tiros que não acertaram inimigos;

tiros_err_col = pegaColunas(df_final, 'quantidadeTirosErrados_')
tiros_err_mean = tiros_err_col.mean().values[1:]
tiros_err_std = tiros_err_col.std().values[1:]

n_groups = 9

fig,ax = plt.subplots(figsize=(10, 5))
index = np.arange(n_groups)[1:]
bar_width = 0.35
opacity = 0.8
sns.set_style("whitegrid")

rects1 = plt.bar(index  , tiros_err_mean , bar_width  , alpha = opacity, color = 'b', yerr = tiros_err_std)
plt.xlabel('Níveis')
plt.ylabel('Tiros Errados')
plt.title('Tiros Errados x Nível')
plt.xticks(index , (index))
plt.legend()
#fig.figure(figsize=(20,20))
#plt.tight_layout()
fig.savefig('tirosErradosXnivel.png')
# Out:
# No handles with labels found to put in legend.

# %%
#nivel x  tiros gastos

col = pegaColunas(df_final, 'quantidadeTiros_')
col_mean = col.mean().values[1:]
col_std = col.std().values[1:]

n_groups = 9

fig,ax = plt.subplots(figsize=(10, 5))
index = np.arange(n_groups)[1:]
bar_width = 0.35
opacity = 0.8
sns.set_style("whitegrid")

rects1 = plt.bar(index  , col_mean , bar_width  , alpha = opacity, color = 'b', yerr = col_std)
plt.xlabel('Níveis')
plt.ylabel('Tiros gastos')
plt.title('Tiros gastos x Nível')
plt.xticks(index , (index))
plt.legend()
#fig.figure(figsize=(20,20))
#plt.tight_layout()
fig.savefig('tirosGastosXnivel.png')
# Out:
# No handles with labels found to put in legend.

# %%
#nivel x  pulos

col = pegaColunas(df_final, 'quantidadePulos_')
col_mean = col.mean().values[1:]
col_std = col.std().values[1:]

n_groups = 9

fig,ax = plt.subplots(figsize=(10, 5))
index = np.arange(n_groups)[1:]
bar_width = 0.35
opacity = 0.8
sns.set_style("whitegrid")

rects1 = plt.bar(index  , col_mean , bar_width  , alpha = opacity, color = 'b', yerr = col_std)
plt.xlabel('Níveis')
plt.ylabel('pulos')
plt.title('Pulos x Nível')
plt.xticks(index , (index))
plt.legend()
#fig.figure(figsize=(20,20))
#plt.tight_layout()
fig.savefig('pulosXnivel.png')
# Out:
# No handles with labels found to put in legend.

# %%
#nivel x  dist Perc

col = pegaColunas(df_final, 'distanciaPercorrida_')
col_mean = col.mean().values[1:]
col_std = col.std().values[1:]

n_groups = 9

fig,ax = plt.subplots(figsize=(10, 5))
index = np.arange(n_groups)[1:]
bar_width = 0.35
opacity = 0.8
sns.set_style("whitegrid")

rects1 = plt.bar(index  , col_mean , bar_width  , alpha = opacity, color = 'b', yerr = col_std)
plt.xlabel('Níveis')
plt.ylabel('Distância Percorrida')
plt.title('Distância Percorrida x Nível')
plt.xticks(index , (index))
plt.legend()
#fig.figure(figsize=(20,20))
#plt.tight_layout()
fig.savefig('dist_percXnivel.png')
# Out:
# No handles with labels found to put in legend.
